# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_pages(page):
    reqUrl = f"https://github.com/topics?page={page}"
    return reqUrl

# %%
def get_page_content(page_url):
    try:
        response = requests.get(page_url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f'An error occurred while requesting the page: {e}')
        return None

    page_doc = BeautifulSoup(response.text, 'html.parser')
    return page_doc

# %%
def get_topic_title(doc):
    topic_title_tag = doc.find_all(
        'p', {'class': 'f3 lh-condensed mb-0 mt-1 Link--primary'})
    if not topic_title_tag:
        raise Exception('Could not find topic title tags')
    topic_title = []
    for item in topic_title_tag:
        topic_title.append(item.text.strip())
    return topic_title


def get_topic_desc(doc):
    topic_desc_tag = doc.find_all(
        'p', {'class': 'f5 color-fg-muted mb-0 mt-1'})
    if not topic_desc_tag:
        raise Exception('Could not find topic description tags')
    topic_desc = []
    for item in topic_desc_tag:
        topic_desc.append(item.text.strip())
    return topic_desc


def get_topic_url(doc):
    topic_url_tag = doc.find_all(
        'a', {'class': 'no-underline flex-1 d-flex flex-column'})
    if not topic_url_tag:
        raise Exception('Could not find topic URL tags')
    base_url = 'https://github.com'
    topic_url = []
    for item in topic_url_tag:
        topic_url.append(base_url + item['href'])
    return topic_url


def scrape_topics_info(page_doc):
    try:
        topics_dict = {
            'topic_title': get_topic_title(page_doc),
            'topic_desc': get_topic_desc(page_doc),
            'topic_url': get_topic_url(page_doc)
        }
    except Exception as e:
        print(f'An error occurred while extracting topic information: {e}')
        return None

    return pd.DataFrame(topics_dict)


def import_to_csv(dataFrame):
    try:
        dataFrame.to_csv('./topics/topics.csv', index=None)
    except Exception as e:
        print(f'An error occurred while writing to the CSV file: {e}')


def update_and_filter_data(new_df):
    try:
        re_index = [*range(100, len(new_df))]
        update_df = new_df.drop(re_index)
    except Exception as e:
        print(f'An error occurred while filtering data: {e}')
        return

    import_to_csv(update_df)

# %%
def access_topic_page_url(df, topic_num):
    try:
        return df['topic_url'][topic_num]
    except KeyError:
        print(
            f"Error: The topic_num '{topic_num}' is not found in the dataframe.")
        return None


def parse_star_count(stars_str):
    try:
        stars_str = stars_str.strip()
        if stars_str[-1] == 'k':
            return int(float(stars_str[:-1])*1000)
        else:
            return int(stars_str)
    except ValueError:
        print(f"Error: Unable to parse the string '{stars_str}' as a number.")
        return None


def get_repo_info(repo_tag, star_tag):
    base_url = 'https://github.com'
    try:
        a_tag = repo_tag.find_all('a')
        username = a_tag[0].text.strip()
        repo_name = a_tag[1].text.strip()
        stars = parse_star_count(star_tag.text.strip())
        repo_url = base_url + a_tag[1]['href']
        return username, repo_name, stars, repo_url
    except (AttributeError, IndexError) as e:
        print(f"Error: {str(e)}")
        return None, None, None, None


def get_topic_repos(topic_doc):
    try:
        repo_tag = topic_doc.find_all(
            'h3', {'class': 'f3 color-fg-muted text-normal lh-condensed'})
        star_tag = topic_doc.find_all(
            'span', {'class': 'Counter js-social-count'})
    except AttributeError as e:
        print(f"Error: {str(e)}")
        return None

    topic_repos_dict = {
        'username': [],
        'repo_name': [],
        'stars': [],
        'repo_url': []
    }

    for i in range(len(repo_tag)):
        repo_info = get_repo_info(repo_tag[i], star_tag[i])
        topic_repos_dict['username'].append(repo_info[0])
        topic_repos_dict['repo_name'].append(repo_info[1])
        topic_repos_dict['stars'].append(repo_info[2])
        topic_repos_dict['repo_url'].append(repo_info[3])
    return pd.DataFrame(topic_repos_dict)


def import_topic_repos_to_csv(df, topic):
    try:
        df.to_csv(f'./topics/repos/{topic}.csv', index=None)
    except Exception as e:
        print(f"Error: Unable to write to file. {str(e)}")

# %%
import os
import pandas as pd

# Step 1: Initialize an empty DataFrame
temp_df = pd.DataFrame()

# Step 2: Iterate through pages and collect data
for page in range(1, 6):
    if len(temp_df) < 100:  # Limit the DataFrame to 100 rows
        try:
            # Assuming these functions are defined elsewhere
            url = get_pages(page)
            page_doc = get_page_content(url)
            df = scrape_topics_info(page_doc)
            temp_df = pd.concat([temp_df, df], ignore_index=True)  # Use pd.concat instead of append
        except Exception as e:
            print(f"Error in page {page}: {e}")
            continue
    else:
        break

# Step 3: Ensure the output directory exists
output_dir = './topics'
output_file = f'{output_dir}/topics.csv'

try:
    # Create the directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Save DataFrame to CSV if it contains data
    if not temp_df.empty:
        temp_df.to_csv(output_file, index=False)
        print(f"Data saved to {output_file}")
    else:
        print("No data collected to save to CSV.")
except Exception as e:
    print(f"Error saving to CSV: {e}")

# Step 4: Read the CSV and process topic repositories
try:
    if os.path.exists(output_file):
        new_df = pd.read_csv(output_file)
        
        for page in range(len(new_df)):
            try:
                url = access_topic_page_url(new_df, page)  # Assuming this function is defined
                doc = get_page_content(url)
                df = get_topic_repos(doc)  # Assuming this function is defined
                
                # Save repositories to a separate CSV
                topic_csv = f"{output_dir}/{new_df['topic_title'][page]}_repos.csv"
                df.to_csv(topic_csv, index=False)
                print(f"Topic repositories saved to {topic_csv}")
            except Exception as e:
                print(f"Error processing topic page {page}: {e}")
                continue
    else:
        print(f"No file found at {output_file} to read topic data.")
except Exception as e:
    print(f"Error reading from CSV: {e}")
# Out:
# Data saved to ./topics/topics.csv
# Topic repositories saved to ./topics/3D_repos.csv
# Topic repositories saved to ./topics/Ajax_repos.csv
# Topic repositories saved to ./topics/Algorithm_repos.csv
# Topic repositories saved to ./topics/Amp_repos.csv
# Topic repositories saved to ./topics/Android_repos.csv
# Topic repositories saved to ./topics/Angular_repos.csv
# Topic repositories saved to ./topics/Ansible_repos.csv
# Topic repositories saved to ./topics/API_repos.csv
# Topic repositories saved to ./topics/Arduino_repos.csv
# Topic repositories saved to ./topics/ASP.NET_repos.csv
# Topic repositories saved to ./topics/Awesome Lists_repos.csv
# Topic repositories saved to ./topics/Amazon Web Services_repos.csv
# Topic repositories saved to ./topics/Azure_repos.csv
# Topic repositories saved to ./topics/Babel_repos.csv
# Topic repositories saved to ./topics/Bash_repos.csv
# Topic repositories saved to ./topics/Bitcoin_repos.csv
# Topic repositories saved to ./topics/Bootstrap_repos.csv
# Topic repositories saved to ./topics/Bot_repos.csv
# Topic repositories saved to ./topics/C_repos.csv
# Topic repositories saved to ./topics/Chrome_repos.csv
# Topic repositories saved to ./topics/Chrome extension_repos.csv
# Topic repositories saved to ./topics/Command-line interface_repos.csv
# Topic repositories saved to ./topics/Clojure_repos.csv
# Topic repositories saved to ./topics/Code quality_repos.csv
# Topic repositories saved to ./topics/Code review_repos.csv
# Topic repositories saved to ./topics/Compiler_repos.csv
# Topic repositories saved to ./topics/Continuous integration_repos.csv
# Topic repositories saved to ./topics/C++_repos.csv
# Topic repositories saved to ./topics/Cryptocurrency_repos.csv
# Topic repositories saved to ./topics/Crystal_repos.csv
# Topic repositories saved to ./topics/C#_repos.csv
# Topic repositories saved to ./topics/CSS_repos.csv
# Topic repositories saved to ./topics/Data structures_repos.csv
# Topic repositories saved to ./topics/Data visualization_repos.csv
# Topic repositories saved to ./topics/Database_repos.csv
# Topic repositories saved to ./topics/Deep learning_repos.csv
# Topic repositories saved to ./topics/Dependency management_repos.csv
# Topic repositories saved to ./topics/Deployment_repos.csv
# Topic repositories saved to ./topics/Django_repos.csv
# Topic repositories saved to ./topics/Docker_repos.csv
# Topic repositories saved to ./topics/Documentation_repos.csv
# Topic repositories saved to ./topics/.NET_repos.csv
# Topic repositories saved to ./topics/Electron_repos.csv
# Topic repositories saved to ./topics/Elixir_repos.csv
# Topic repositories saved to ./topics/Emacs_repos.csv
# Topic repositories saved to ./topics/Ember_repos.csv
# Topic repositories saved to ./topics/Emoji_repos.csv
# Topic repositories saved to ./topics/Emulator_repos.csv
# Topic repositories saved to ./topics/ESLint_repos.csv
# Topic repositories saved to ./topics/Ethereum_repos.csv
# Topic repositories saved to ./topics/Express_repos.csv
# Topic repositories saved to ./topics/Firebase_repos.csv
# Topic repositories saved to ./topics/Firefox_repos.csv
# Topic repositories saved to ./topics/Flask_repos.csv
# Topic repositories saved to ./topics/Font_repos.csv
# Topic repositories saved to ./topics/Framework_repos.csv
# Topic repositories saved to ./topics/Front end_repos.csv
# Topic repositories saved to ./topics/Game engine_repos.csv
# Topic repositories saved to ./topics/Git_repos.csv
# Topic repositories saved to ./topics/GitHub API_repos.csv
# Topic repositories saved to ./topics/Go_repos.csv
# Topic repositories saved to ./topics/Google_repos.csv
# Topic repositories saved to ./topics/Gradle_repos.csv
# Topic repositories saved to ./topics/GraphQL_repos.csv
# Topic repositories saved to ./topics/Gulp_repos.csv
# Topic repositories saved to ./topics/Hacktoberfest_repos.csv
# Topic repositories saved to ./topics/Haskell_repos.csv
# Topic repositories saved to ./topics/Homebrew_repos.csv
# Topic repositories saved to ./topics/Homebridge_repos.csv
# Topic repositories saved to ./topics/HTML_repos.csv
# Topic repositories saved to ./topics/HTTP_repos.csv
# Topic repositories saved to ./topics/Icon font_repos.csv
# Topic repositories saved to ./topics/iOS_repos.csv
# Topic repositories saved to ./topics/IPFS_repos.csv
# Topic repositories saved to ./topics/Java_repos.csv
# Topic repositories saved to ./topics/JavaScript_repos.csv
# Topic repositories saved to ./topics/Jekyll_repos.csv
# Topic repositories saved to ./topics/jQuery_repos.csv
# Topic repositories saved to ./topics/JSON_repos.csv
# Topic repositories saved to ./topics/The Julia Language_repos.csv
# Topic repositories saved to ./topics/Jupyter Notebook_repos.csv
# Topic repositories saved to ./topics/Koa_repos.csv
# Topic repositories saved to ./topics/Kotlin_repos.csv
# Topic repositories saved to ./topics/Kubernetes_repos.csv
# Topic repositories saved to ./topics/Laravel_repos.csv
# Topic repositories saved to ./topics/LaTeX_repos.csv
# Topic repositories saved to ./topics/Library_repos.csv
# Topic repositories saved to ./topics/Linux_repos.csv
# Topic repositories saved to ./topics/Localization (l10n)_repos.csv
# Topic repositories saved to ./topics/Lua_repos.csv
# Topic repositories saved to ./topics/Machine learning_repos.csv
# Topic repositories saved to ./topics/macOS_repos.csv
# Topic repositories saved to ./topics/Markdown_repos.csv
# Topic repositories saved to ./topics/Mastodon_repos.csv
# Topic repositories saved to ./topics/Material Design_repos.csv
# Topic repositories saved to ./topics/MATLAB_repos.csv
# Topic repositories saved to ./topics/Maven_repos.csv
# Topic repositories saved to ./topics/Minecraft_repos.csv
# Topic repositories saved to ./topics/Mobile_repos.csv
# Topic repositories saved to ./topics/Monero_repos.csv
# Topic repositories saved to ./topics/MongoDB_repos.csv
# Topic repositories saved to ./topics/Mongoose_repos.csv
# Topic repositories saved to ./topics/Monitoring_repos.csv
# Topic repositories saved to ./topics/MvvmCross_repos.csv
# Topic repositories saved to ./topics/MySQL_repos.csv
# Topic repositories saved to ./topics/NativeScript_repos.csv
# Topic repositories saved to ./topics/Nim_repos.csv
# Topic repositories saved to ./topics/Natural language processing_repos.csv
# Topic repositories saved to ./topics/Node.js_repos.csv
# Topic repositories saved to ./topics/NoSQL_repos.csv
# Topic repositories saved to ./topics/npm_repos.csv
# Topic repositories saved to ./topics/Objective-C_repos.csv
# Topic repositories saved to ./topics/OpenGL_repos.csv
# Topic repositories saved to ./topics/Operating system_repos.csv
# Topic repositories saved to ./topics/P2P_repos.csv
# Topic repositories saved to ./topics/Package manager_repos.csv
# Topic repositories saved to ./topics/Parsing_repos.csv
# Topic repositories saved to ./topics/Perl_repos.csv
# Topic repositories saved to ./topics/Phaser_repos.csv
# Topic repositories saved to ./topics/PHP_repos.csv
